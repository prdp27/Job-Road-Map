# %% [markdown]
# # Pradeep Kumar Barolia
# Delhi, India
# Data Analyst | BI Analyst | Data Science Aspirant
# Email: [Your Email] | Phone: [Your Number]
#
# ---
#
# # PROFESSIONAL SUMMARY
#
# Experienced professional with 20+ years across office administration, logistics, system management, and application support. Since 2026, actively working in Data Analytics using Python (Pandas, NumPy), SQL, Excel, and Power BI to generate business insights and automate reporting systems.
#
# Strong expertise in financial reporting, inventory analysis, and operational data management with proven ability to improve business efficiency through data-driven decision-making.
#
# ---
#
# # CORE SKILLS
#
# - Power BI (Dashboards, Data Visualization)
# - Python (Pandas, NumPy)
# - SQL (Basic–Intermediate)
# - Excel (Advanced Reporting, Pivot Tables)
# - Financial & Business Reporting
# - Data Cleaning & Analysis
#
# ---
#
# # PROFESSIONAL EXPERIENCE
#
# ## Manager Systems EDP
# Anuradha Enterprises Pvt. Ltd., New Delhi
# April 2022 – Present
#
# - Developed financial and inventory reports using Excel and Busy software
# - Since 2026, automated reporting using Python and Power BI
# - Built reports: sales, purchase, stock, receivables, payables
# - Improved business decision-making through analytics
#
# ---
#
# ## Executive Systems EDP
# March 2018 – March 2022
#
# - Managed accounting operations using Busy software
# - Created invoices, purchase orders, pricing reports
# - Provided IT support and system troubleshooting
#
# ---
#
# ## Logistics & Operations Roles
# 2012 – 2018
#
# - Managed logistics coordination and business operations
# - Supported sales, dispatch, and customer communication
#
# ---
#
# ## Early Career
# 2004 – 2012
#
# - Office administration, reporting, customer support, data handling
#
# ---
#
# # EDUCATION
#
# - Higher Secondary (12th) – NIOS India (2006)
# - Secondary School (10th) – NIOS India (2004)
#
# ---
#
# # CERTIFICATIONS
#
# - Master in Data Science with Power BI (Ongoing)
# - Visual FoxPro Certification (2008)
#
# ---
#
# # LANGUAGES
#
# - Hindi (Native)
# - English (B2 Professional)
#
# ---
#
# # TARGET ROLES
#
# - Data Analyst
# - BI Analyst
# - Reporting Analyst
# - Power BI Developer
