# %% [markdown]
# # CURRICULUM VITAE
#
# ## Pradeep Kumar Barolia
# Delhi, India
# Email: [Your Email]
# Phone: [Your Phone]
#
# ---
#
# ## PROFESSIONAL SUMMARY
#
# Data-driven professional with 20+ years of experience in office administration, logistics, system management, and application support. Since 2026, actively working in Data Analytics using Python (Pandas, NumPy), SQL, Excel, and Power BI to generate business insights and automate reporting systems.
#
# Strong experience in financial reporting, inventory analysis, and business operations with proven ability to improve efficiency through data-driven decision making.
#
# ---
#
# ## SKILLS
#
# ### Data & Analytics
# - Power BI (Dashboards, Reporting)
# - Excel (Advanced formulas, Pivot tables)
# - Python (Pandas, NumPy)
# - SQL (Basic–Intermediate)
#
# ### Business Skills
# - Financial Reporting
# - Inventory Management
# - Operations Analysis
# - Process Optimization
#
# ### Technical Skills
# - Basic System Administration
# - Data Handling & Reporting
# - Software Support
#
# ---
#
# ## EXPERIENCE
#
# ### Manager Systems EDP
# Anuradha Enterprises Pvt. Ltd., New Delhi
# April 2022 – Present
#
# - Developed and maintained financial and inventory reports using Excel and Busy software.
# - Since 2026, automated reporting using Python (Pandas, NumPy) and Power BI.
# - Built reports including sales, purchase, stock, receivables, and payables analysis.
# - Improved decision-making through accurate and timely reporting.
#
# ---
#
# ### Executive Systems EDP
# March 2018 – March 2022
#
# - Managed billing and accounting systems using Busy software.
# - Created purchase orders, invoices, and pricing reports.
# - Provided technical support including system installation and troubleshooting.
#
# ---
#
# ### Logistics & Operations Roles
# 2012 – 2018
#
# - Managed logistics coordination for transport and operations.
# - Supported sales, dispatch, and customer communication.
#
# ---
#
# ### Early Career Roles
# 2004 – 2012
#
# - Office administration, reporting, customer support, and data handling roles.
# - Worked with legacy systems and business reporting tools.
#
# ---
#
# ## EDUCATION
#
# - Higher Secondary (12th), National Institute of Open Schooling (2006)
# - Secondary School (10th), National Institute of Open Schooling (2004)
#
# ---
#
# ## CERTIFICATIONS
#
# - Master in Data Science with Power BI (Ongoing)
# - Visual FoxPro Certification (2008)
#
# ---
#
# ## LANGUAGES
#
# - Hindi (Native)
# - English (Professional – B2)
#
# ---
#
# ## TARGET ROLES
#
# - Data Analyst
# - BI Analyst
# - Reporting Analyst
# - Power BI Developer
#
# ---
#
# ## ADDITIONAL INFORMATION
#
# - Strong experience in business operations and data reporting
# - Currently transitioning into Data Science & Analytics
# - Highly motivated to work in data-driven environments in Europe
