# %% [markdown]
# # Pradeep Kumar Barolia
# Data Analyst | BI Analyst | Python | Power BI | SQL | Reporting
# Delhi, India | Email: [Your Email] | Phone: [Your Number]
#
# ---
#
# ## Professional Summary
# Data Analyst with 20+ years of experience in office administration, logistics, and system management. Experienced in transforming financial and operational data into actionable insights. Skilled in Python (Pandas, NumPy), Power BI, SQL, and Excel for reporting automation and dashboards. Strong understanding of business processes and data-driven decision-making.
#
# ---
#
# ## Core Skills
# - **Data Analytics**: Python, Pandas, NumPy, Excel
# - **Data Visualization**: Power BI, Tableau basics
# - **Databases**: SQL Server, MySQL
# - **Business Reporting**: Finance, Inventory, KPI dashboards
# - **ETL & Data Handling**: Data cleaning, transformation
# - **Cloud Platforms**: Azure (basic)
#
# ---
#
# ## Professional Experience
#
# ### Manager Systems EDP | Anuradha Enterprises Pvt. Ltd., New Delhi | Apr 2022 – Present
# - Developed and automated financial, sales, and inventory reports using **Python, Pandas, Power BI, Excel**.
# - Built dashboards for KPI tracking and business insights.
# - Enhanced procurement and financial workflows through automated reporting.
#
# ### Executive Systems EDP | Anuradha Enterprises Pvt. Ltd., New Delhi | Mar 2018 – Mar 2022
# - Managed accounting systems and email workflows for efficient billing.
# - Created purchase orders, invoices, and pricing reports.
# - Provided IT support and system troubleshooting.
#
# ### Logistics & Operations | 2012 – 2018
# - Coordinated logistics and transport for PVR Cinemas and company operations.
# - Assisted in sales, dispatch, and customer communications.
#
# ### Early Career | 2004 – 2012
# - Office administration, reporting, customer support, and data handling roles.
#
# ---
#
# ## Education
# - Master in Data Science with Power BI (Ongoing)
# - Higher Secondary (12th), NIOS India, 2006
# - Secondary School (10th), NIOS India, 2004
#
# ---
#
# ## Certifications
# - Visual FoxPro (2008)
# - Data Science with Power BI (Ongoing)
#
# ---
#
# ## Languages
# - English (B2)
# - Hindi (Native)
#
# ---
#
# ## Target Roles
# - Data Analyst
# - BI Analyst
# - Reporting Analyst
# - Power BI Developer
