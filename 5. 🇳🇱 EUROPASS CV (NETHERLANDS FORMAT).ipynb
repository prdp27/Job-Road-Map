# %% [markdown]
# # CURRICULUM VITAE
#
# ## Personal Information
# Name: Pradeep Kumar Barolia
# Location: Delhi, India
# Nationality: Indian
# Languages: Hindi (Native), English (B2)
#
# ---
#
# ## Professional Summary
#
# Data Analyst with 20+ years of experience in administration, logistics, and system support. Since 2026, working in Data Analytics using Python, SQL, Excel, and Power BI.
#
# Strong background in financial reporting, inventory analysis, and business operations. Skilled in transforming raw data into actionable insights for decision-making.
#
# ---
#
# ## Work Experience
#
# ### Manager Systems EDP
# Anuradha Enterprises Pvt. Ltd.
# 2022 – Present
# - Financial and inventory reporting
# - Python + Power BI automation (since 2026)
# - Business reporting dashboards
#
# ### Executive Systems EDP
# 2018 – 2022
# - Accounting system management (Busy)
# - Reporting and invoicing systems
# - IT support and troubleshooting
#
# ### Logistics & Operations Roles
# 2012 – 2018
# - Logistics coordination
# - Sales and dispatch support
#
# ### Early Career
# 2004 – 2012
# - Office administration and reporting roles
#
# ---
#
# ## Skills
#
# - Data Analysis (Python, SQL, Excel)
# - Power BI Dashboard Development
# - Financial Reporting
# - Business Operations Analysis
# - Data Cleaning & Reporting
#
# ---
#
# ## Education
#
# - 12th Grade – NIOS India (2006)
# - 10th Grade – NIOS India (2004)
#
# ---
#
# ## Certifications
#
# - Data Science with Power BI (Ongoing)
# - Visual FoxPro (2008)
#
# ---
#
# ## Career Objective
#
# To contribute as a Data Analyst / BI Analyst in a European organization by using data-driven insights to improve business performance and decision-making.
