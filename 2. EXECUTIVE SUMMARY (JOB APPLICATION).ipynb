# %% [markdown]
# # Executive Summary
#
# Pradeep Kumar Barolia
# Data Analyst | BI Analyst | Data Science Aspirant
#
# ---
#
# ## Professional Summary
#
# Experienced professional with 20+ years of expertise across office administration, logistics, system management, and application support. Since 2026, actively working in Data Analytics using Python (Pandas, NumPy), Power BI, Excel, and SQL to generate business insights and automate reporting systems.
#
# Strong background in managing operational data, financial reporting, inventory analysis, and business process optimization. Proven ability to transform raw data into meaningful insights that support strategic decision-making.
#
# ---
#
# ## Core Skills
#
# - Power BI (Dashboards, Data Visualization)
# - Python (Pandas, NumPy)
# - SQL (Basic–Intermediate)
# - Excel (Advanced Reporting)
# - Business & Financial Reporting
# - Data Cleaning & Analysis
#
# ---
#
# ## Professional Strengths
#
# - Strong business understanding (20+ years experience)
# - Experience with real-world financial and operational data
# - Ability to bridge legacy systems and modern analytics
# - Fast learner with strong analytical mindset
# - Hands-on experience in reporting automation
#
# ---
#
# ## Target Roles
#
# - Data Analyst
# - BI Analyst
# - Reporting Analyst
# - Power BI Developer
#
# ---
#
# ## Career Objective
#
# To contribute to a data-driven organization by leveraging analytics, reporting, and visualization skills to support better business decisions and operational efficiency.
