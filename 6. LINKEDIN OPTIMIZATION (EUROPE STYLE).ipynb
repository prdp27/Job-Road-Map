# %% [markdown]
# # Headline
# Data Analyst | Power BI | Python (Pandas, NumPy) | SQL | Business Intelligence | Reporting Specialist
#
# ---
#
# # About Section
#
# Experienced professional with 20+ years in administration, logistics, and system support. Currently transitioning into Data Analytics with hands-on experience in Python, Power BI, SQL, and Excel.
#
# I specialize in transforming business and financial data into actionable insights through dashboards, reporting automation, and data analysis.
#
# My experience bridges legacy business systems with modern analytics tools, helping organizations improve efficiency and decision-making.
#
# ---
#
# # Skills
# - Power BI
# - Python (Pandas, NumPy)
# - SQL
# - Excel Advanced
# - Data Analysis
# - Business Reporting
# - Financial Analysis
#
# ---
#
# # Featured Projects (Add later)
# - Sales Dashboard (Power BI)
# - Inventory Analysis System
# - Financial Reporting Automation
